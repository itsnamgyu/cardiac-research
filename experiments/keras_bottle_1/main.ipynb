# %%
import sys
sys.path.append('../..')
import os
import argparse
import tempfile
import warnings
import shutil

import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np
import keras
from tqdm import tqdm
import requests

import keras_utils as ku
import cr_interface as cri
import lib

def notify(string='done'):
    # send a personal notification to Namgyu
    
    headers = {
        'Content-type': 'application/json',
    }
    data = '{"text":"[CREB1] %s"}' % string
    
    response = requests.post('https://hooks.slack.com/services/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', headers=headers, data=data)
# Out:
# Using TensorFlow backend.

# %%
fc = cri.CrCollection.load().sample(frac=0.02).labeled().tri_label()

# %%
BOTTLENECK_DIR = os.path.join(cri.PROJECT_DIR, 'bottlenecks')
TEMP_DIR = os.path.join(cri.PROJECT_DIR, '.keras_bottle_temp')

def _get_temp_dir():
    os.makedirs(TEMP_DIR, exist_ok=True)
    return TEMP_DIR

def get_bottleneck_dir(model, mkdir=True):
    subdir = '{}_{}'.format(model.name.replace('.', '_'), len(model.layers))
    path = os.path.join(BOTTLENECK_DIR, subdir)

    if mkdir:
        os.makedirs(path, exist_ok=True)

    return os.path.abspath(path)

def get_bottleneck_path(model, cr_code, aug, index=0):
    dirname = get_bottleneck_dir(model)
    if aug:
        basename = '{}_AUG_{:d}.npy'.format(cr_code, index)
    else:
        if index != 0:
            warnings.warn('index ignored on aug=False')
        basename = '{}.npy'.format(cr_code)
    return os.path.join(dirname, basename)

def bottleneck_exists(model, cr_code, aug: bool, index=0):
    # optimization considerations: currently takes 35s per 1,0000,000 calls
    return os.path.exists(get_bottleneck_path(model, cr_code, aug, index))

# %%
mobile = ku.applications['mobilenet']
model = mobile.get_model()
collection = cri.CrCollection.load().labeled().filter_by(dataset_index=1)
# Out:
# loading mobilenet model

# %%
def _get_nth_bottleneck_collection(app, collection, aug, index=0, model=None):
    '''
    Filter the collection to leave of just the ones for
    which we need to generate bottlenecks
    '''
    if len(collection.df) == 0:
        warnings.warn('empty collection')
        return collection
    
    if not model:
        model = app.get_model()
        
    def should_generate(cr_code):
        return not bottleneck_exists(model, cr_code, aug, index)
    df = collection.df
    df = df.loc[df.apply(lambda x: should_generate(x['cr_code']), axis=1)]
    df = df.sort_values('cr_code')
    
    return cri.CrCollection(df)

# %%
_get_nth_bottleneck_collection(mobile, fc.filter_by(label='in'), aug=True, index=0).df
# Out:
#                   cr_code  dataset_index    pid  phase_index  slice_index  \
# 0   D00_P00001401_P00_S05              0   1401            0            5
# 1   D00_P00001701_P14_S02              0   1701           14            2
# 2   D00_P00001801_P14_S05              0   1801           14            5
# 3   D00_P00002701_P00_S02              0   2701            0            2
# 4   D00_P00002901_P00_S13              0   2901            0           13
# 5   D00_P00003101_P00_S02              0   3101            0            2
# 6   D00_P00003101_P00_S03              0   3101            0            3
# 7   D00_P00003401_P00_S13              0   3401            0           13
# 8   D00_P00004001_P00_S03              0   4001            0            3
# 9   D00_P00005501_P00_S01              0   5501            0            1
# 10  D00_P00005601_P14_S03              0   5601           14            3
# 11  D00_P00005901_P14_S10              0   5901           14           10
# 12  D00_P00006501_P00_S03              0   6501            0            3
# 13  D00_P00007101_P00_S03              0   7101            0            3
# 14  D00_P00007101_P14_S07              0   7101           14            7
# 15  D00_P00008801_P00_S01              0   8801            0            1
# 16  D00_P00008801_P00_S10              0   8801            0           10
# 17  D00_P00008801_P14_S07              0   8801           14            7
# 18  D00_P00008901_P00_S05              0   8901            0            5
# 19  D00_P00009301_P14_S05              0   9301           14            5
# 20  D00_P00014201_P00_S05              0  14201            0            5
# 21  D00_P00021501_P14_S11              0  21501           14           11
# 22  D00_P00026801_P00_S05              0  26801            0            5
# 23  D00_P00026901_P00_S07              0  26901            0            7
# 24  D00_P00028801_P14_S09              0  28801           14            9
# 25  D00_P00029001_P00_S04              0  29001            0            4
# 26  D00_P00030101_P14_S04              0  30101           14            4
# 27  D00_P00037101_P00_S06              0  37101            0            6
# 28  D00_P00040001_P14_S07              0  40001           14            7
# 29  D00_P00042501_P00_S04              0  42501            0            4
# 30  D00_P00043201_P00_S07              0  43201            0            7
# 31  D00_P00043901_P00_S04              0  43901            0            4
# 32  D00_P00044601_P14_S03              0  44601           14            3
# 33  D00_P00044601_P14_S08              0  44601           14            8
# 34  D00_P00044801_P00_S01              0  44801            0            1
# 35  D01_P00000301_P14_S04              1    301           14            4
# 36  D01_P00000401_P14_S04              1    401           14            4
# 37  D01_P00000901_P00_S06              1    901            0            6
# 38  D01_P00007301_P14_S06              1   7301           14            6
# 39  D01_P00007701_P00_S07              1   7701            0            7
# 40  D01_P00007701_P00_S13              1   7701            0           13
# 41  D01_P00008701_P14_S09              1   8701           14            9
# 42  D01_P00009101_P14_S06              1   9101           14            6
#
#    label         original_name  \
# 0     in    DET0001401_SA8_ph0
# 1     in   DET0001701_SA3_ph14
# 2     in   DET0001801_SA6_ph14
# 3     in   DET0002701_SA10_ph0
# 4     in    DET0002901_SA3_ph0
# 5     in   DET0003101_SA12_ph0
# 6     in   DET0003101_SA11_ph0
# 7     in    DET0003401_SA4_ph0
# 8     in   DET0004001_SA11_ph0
# 9     in    DET0005501_SA2_ph0
# 10    in   DET0005601_SA4_ph14
# 11    in   DET0005901_SA6_ph14
# 12    in    DET0006501_SA7_ph0
# 13    in    DET0007101_SA9_ph0
# 14    in   DET0007101_SA5_ph14
# 15    in   DET0008801_SA12_ph0
# 16    in    DET0008801_SA3_ph0
# 17    in   DET0008801_SA6_ph14
# 18    in    DET0008901_SA8_ph0
# 19    in   DET0009301_SA4_ph14
# 20    in    DET0014201_SA6_ph0
# 21    in  DET0021501_SA12_ph14
# 22    in    DET0026801_SA6_ph0
# 23    in    DET0026901_SA8_ph0
# 24    in   DET0028801_SA2_ph14
# 25    in    DET0029001_SA6_ph0
# 26    in   DET0030101_SA5_ph14
# 27    in    DET0037101_SA4_ph0
# 28    in   DET0040001_SA3_ph14
# 29    in    DET0042501_SA7_ph0
# 30    in    DET0043201_SA4_ph0
# 31    in    DET0043901_SA8_ph0
# 32    in   DET0044601_SA4_ph14
# 33    in   DET0044601_SA9_ph14
# 34    in   DET0044801_SA11_ph0
# 35    in   DET0000301_SA5_ph14
# 36    in   DET0000401_SA5_ph14
# 37    in   DET0000901_SA11_ph0
# 38    in   DET0007301_SA8_ph14
# 39    in    DET0007701_SA8_ph0
# 40    in   DET0007701_SA14_ph0
# 41    in  DET0008701_SA10_ph14
# 42    in   DET0009101_SA7_ph14
#
#                                     original_filepath
# 0     cap_challenge/DET0001401/DET0001401_SA8_ph0.dcm
# 1   /Users/release/.ho/cardiac-research/slice_rang...
# 2   /Users/release/.ho/cardiac-research/slice_rang...
# 3    cap_challenge/DET0002701/DET0002701_SA10_ph0.dcm
# 4     cap_challenge/DET0002901/DET0002901_SA3_ph0.dcm
# 5    cap_challenge/DET0003101/DET0003101_SA12_ph0.dcm
# 6    cap_challenge/DET0003101/DET0003101_SA11_ph0.dcm
# 7     cap_challenge/DET0003401/DET0003401_SA4_ph0.dcm
# 8    cap_challenge/DET0004001/DET0004001_SA11_ph0.dcm
# 9     cap_challenge/DET0005501/DET0005501_SA2_ph0.dcm
# 10  /Users/release/.ho/cardiac-research/slice_rang...
# 11  /Users/release/.ho/cardiac-research/slice_rang...
# 12    cap_challenge/DET0006501/DET0006501_SA7_ph0.dcm
# 13    cap_challenge/DET0007101/DET0007101_SA9_ph0.dcm
# 14  /Users/release/.ho/cardiac-research/slice_rang...
# 15   cap_challenge/DET0008801/DET0008801_SA12_ph0.dcm
# 16    cap_challenge/DET0008801/DET0008801_SA3_ph0.dcm
# 17  /Users/release/.ho/cardiac-research/slice_rang...
# 18    cap_challenge/DET0008901/DET0008901_SA8_ph0.dcm
# 19  /Users/release/.ho/cardiac-research/slice_rang...
# 20    cap_challenge/DET0014201/DET0014201_SA6_ph0.dcm
# 21  /Users/release/.ho/cardiac-research/slice_rang...
# 22    cap_challenge/DET0026801/DET0026801_SA6_ph0.dcm
# 23    cap_challenge/DET0026901/DET0026901_SA8_ph0.dcm
# 24  /Users/release/.ho/cardiac-research/slice_rang...
# 25    cap_challenge/DET0029001/DET0029001_SA6_ph0.dcm
# 26  /Users/release/.ho/cardiac-research/slice_rang...
# 27    cap_challenge/DET0037101/DET0037101_SA4_ph0.dcm
# 28  /Users/release/.ho/cardiac-research/slice_rang...
# 29    cap_challenge/DET0042501/DET0042501_SA7_ph0.dcm
# 30    cap_challenge/DET0043201/DET0043201_SA4_ph0.dcm
# 31    cap_challenge/DET0043901/DET0043901_SA8_ph0.dcm
# 32  /Users/release/.ho/cardiac-research/slice_rang...
# 33  /Users/release/.ho/cardiac-research/slice_rang...
# 34   cap_challenge/DET0044801/DET0044801_SA11_ph0.dcm
# 35  /Users/release/.ho/cardiac-research/slice_rang...
# 36  /Users/release/.ho/cardiac-research/slice_rang...
# 37  cap_challenge_validation/Validation/CAP_challe...
# 38  /Users/release/.ho/cardiac-research/slice_rang...
# 39  cap_challenge_validation/Validation/CAP_challe...
# 40  cap_challenge_validation/Validation/CAP_challe...
# 41  /Users/release/.ho/cardiac-research/slice_rang...
# 42  /Users/release/.ho/cardiac-research/slice_rang...

# %%
def generate_bottlenecks(app, base_collection, aug, count=1, model=None, verbose=1):
    if len(base_collection.df) == 0:
        warnings.warn('empty collection')
        return
    if count != 1 and not aug:
        warnings.warn('count ignored when aug is false')
        count = 1
    if not model:
        model = app.get_model()

    total = 0
    collections = []
    for i in range(count):
        c = _get_nth_bottleneck_collection(
            app, base_collection, model=model, aug=aug, index=i)
        collections.append(c)
        total += len(c.df)

    print('loading {} of {} * {} bottlenecks'.format(
        total, len(base_collection.df), count))

    done = 0
    for index, collection in enumerate(collections):
        if len(collection.df) == 0: continue

        temp = _get_temp_dir()
        image_dir = os.path.join(temp, 'images')
        shutil.rmtree(image_dir, ignore_errors=True)
        default_class = os.path.join(image_dir, 'default_class')

        collection.export(default_class, by_label=False)

        gen = app.get_image_data_generator(augment=aug).flow_from_directory(
            image_dir,
            target_size=app.image_size,
            batch_size=128,
        )

        data = model.predict_generator(gen)

        temp_bottle_path = os.path.join(temp, 'temp.npy')
        for i, cr_code in enumerate(collection.get_cr_codes()):
            # prevent corrupt data in main bottleneck directory
            path = get_bottleneck_path(model, cr_code, aug, index=index)
            np.save(temp_bottle_path, data[i])
            os.rename(temp_bottle_path, path)

        done += len(collection.df)

# %%
def generate_all_bottlenecks(app, collection=None, augmentation=5, balancing=5):
    if collection:
        c = collection.tri_label()
        if len(c.df) == 0:
            warnings.warn('empty collection')
            return
    else:
        c = cri.CrCollection.load().labeled().tri_label()
        
    c0 = c.filter_by(dataset_index=0)
    c1 = c.filter_by(dataset_index=1)
    
    c0_out = c0.filter_by(label=['oap', 'obs'])
    c0_in = c0.filter_by(label='in')
    c1_out = c1.filter_by(label=['oap', 'obs'])
    c1_in = c1.filter_by(label='in')
    
    print('(1/3) loading unaugmented bottlenecks'.center(100, '-'))
    generate_bottlenecks(app, c, aug=False)
    
    print('(2/3) loading train bottlenecks (in)'.center(100, '-'))
    generate_bottlenecks(app, c0_in, aug=True, count=augmentation)
    
    print('(3/3) loading train bottlenecks (out)'.center(100, '-'))
    generate_bottlenecks(app, c0_out, aug=True, count=augmentation * balancing)

# %%
try:
    generate_all_bottlenecks(mobile, collection=fc, augmentation=5, balancing=5)
finally:
    notify()
# Out:
# -------------------------------(1/5) loading unaugmented bottlenecks--------------------------------
# loading 0 of 57 * 1 bottlenecks
# --------------------------------(2/5) loading train bottlenecks (in)--------------------------------
# loading 0 of 35 * 5 bottlenecks
# -------------------------------(3/5) loading train bottlenecks (out)--------------------------------
# loading 0 of 12 * 25 bottlenecks
# --------------------------------(4/5) loading test bottlenecks (in)---------------------------------
# loading 0 of 8 * 1 bottlenecks
# --------------------------------(5/5) loading test bottlenecks (out)--------------------------------
# loading 0 of 2 * 1 bottlenecks

# %%
try:
    generate_all_bottlenecks(ku.applications['inceptionresnetv2'],
                             collection=cri.CrCollection.load().sample(frac=0.025),
                             augmentation=5, balancing=5)
finally:
    notify()
# Out:
# -------------------------------(1/5) loading unaugmented bottlenecks--------------------------------
# loading 122 of 126 * 1 bottlenecks
# Found 122 images belonging to 1 classes.
# --------------------------------(2/5) loading train bottlenecks (in)--------------------------------
# loading 229 of 46 * 5 bottlenecks
# Found 45 images belonging to 1 classes.
# Found 46 images belonging to 1 classes.
# Found 46 images belonging to 1 classes.
# Found 46 images belonging to 1 classes.
# Found 46 images belonging to 1 classes.
# -------------------------------(3/5) loading train bottlenecks (out)--------------------------------
# loading 375 of 15 * 25 bottlenecks
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# --------------------------------(4/5) loading test bottlenecks (in)---------------------------------
# loading 0 of 8 * 1 bottlenecks
# --------------------------------(5/5) loading test bottlenecks (out)--------------------------------
# loading 0 of 1 * 1 bottlenecks
