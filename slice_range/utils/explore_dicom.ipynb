# %%
import os

import pydicom
import scipy.misc
import matplotlib.pyplot as plt

# %%
def preview_dicom(path):
    dcm = pydicom.dcmread(path)
    return plt.imshow(dcm.pixel_array)

# %%
preview_dicom('../datasets/cine/001/63/anon_ser063img00001.dcm')
